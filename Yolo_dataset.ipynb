# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/Computer-vision-practice/blob/main/Yolo_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Vf51w6PDloBEGS4kFg6u")
project = rf.workspace("cv-sw-bns7k").project("trafic-rzjnr")
version = project.version(8)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 65.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to trafic-8 in yolov5pytorch:: 100%|██████████| 2012/2012 [00:00<00:00, 3874.71it/s]

# %%
img_labels='/content/trafic-8/train/labels/Driving-Downtown-New-York-City-4K-USA_mp4-0000_jpg.rf.960ef0b0b40bbfd86238384b08cb7953.txt'

# %%
boxes=[]
labels=[]
with open(img_labels) as f:
    lines = f.readlines()

for line in lines:

    class_id, xc, yc, w, h = map(float, line.split())

    labels.append(int(class_id))
    boxes.append([xc, yc, w, h])

# %%
boxes
# Out:
# [[0.1171875, 0.7265625, 0.234375, 0.1875],
#  [0.4765625, 0.70859375, 0.2625, 0.21015625],
#  [0.2515625, 0.678125, 0.08203125, 0.125],
#  [0.21875, 0.775, 0.01484375, 0.0234375],
#  [0.80078125, 0.696875, 0.01328125, 0.01875],
#  [0.625, 0.72109375, 0.04609375, 0.28359375],
#  [0.84609375, 0.721875, 0.0203125, 0.09765625],
#  [0.98515625, 0.6734375, 0.02578125, 0.090625],
#  [0.93984375, 0.65078125, 0.01328125, 0.0390625]]

# %%
labels
# Out:
# [0, 0, 0, 1, 1, 2, 2, 2, 2]
